# %%
#importing libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel("./drive/My Drive/data/food.xlsx")
df_v1=df

# %%
df_v1.columns
# Out:
# Index(['app', 'item', 'original price', 'I paid', 'date', 'time',
#        'delivery location', 'zunk food', 'fat food', 'sweet', 'type',
#        'healthy', 'no.of items', 'mealtype', 'restaurent', 'payment mode'],
#       dtype='object')

# %%
df_v1.restaurent=df_v1.restaurent.replace("eatfit","eat fit")

# %%
df_v1['restaurent']=df_v1['restaurent'].str.title()

# %%
wc= df_v1.restaurent.values

# %%
df_v1.restaurent.count()
# Out:
# 79

# %%
df_v1.restaurent.nunique()
# Out:
# 39

# %%
dic=df_v1.restaurent.value_counts()

# %%
dic
# Out:
# A2B                    8
# Faasos                 6
# Eat Fit                6
# Bowl Company           5
# Rajdhani               5
# Fresh Menu             5
# Udupi Park             4
# Ccd                    3
# Homely                 3
# Cold Stone Creamery    2
# Keventers              2
# Chai Resto             2
# Wow Momo               2
# Yum Yum Dilli          1
# Petoo                  1
# Chocolate Heaven       1
# Hyd Biriyani House     1
# Warm Oven              1
# Dominos                1
# Friends Own            1
# Delhi Kitchen          1
# Nu.Tree                1
# Imperio                1
# Chai Point             1
# Maa Bhook Lagi         1
# Madurai Express        1
# Rice Bowl              1
# Beyond Elements        1
# Pindi Bangalore        1
# Box 8                  1
# Refresh                1
# Mad Over Donuts        1
# Flavours Of India      1
# Stoner                 1
# Taco Bell              1
# Indulge                1
# Kitchens               1
# ...

# %%
wc
# Out:
# array(['Faasos', 'Faasos', 'Eat Fit', 'Eat Fit', 'Friends Own', 'A2B',
#        'Bowl Company', 'Chai Resto', 'Rice Bowl', 'Grow Fit',
#        'Maa Bhook Lagi', 'Bowl Company', 'Bowl Company', 'A2B',
#        'Bowl Company', 'A2B', 'A2B', 'Fresh Menu', 'Homely', 'Homely',
#        'Faasos', 'Petoo', 'Refresh', 'A2B', 'A2B', 'A2B', 'Bowl Company',
#        'A2B', 'Homely', 'Keventers', 'Eat Fit', 'Pindi Bangalore',
#        'Box 8', 'Fresh Menu', 'Eat Fit', 'Rajdhani', 'Udupi Park',
#        'Kitchens', 'Ccd', 'Yum Yum Dilli', 'Warm Oven', 'Eat Fit',
#        'Eat Fit', 'Taco Bell', 'Cold Stone Creamery', 'Fresh Menu',
#        'Cold Stone Creamery', 'Mad Over Donuts', 'Rajdhani', 'Indulge',
#        'Ccd', 'Hyd Biriyani House', 'Fresh Menu', 'Udupi Park',
#        'Keventers', 'Nu.Tree', 'Madurai Express ', 'Chai Resto',
#        'Udupi Park', 'Chandrika Tiffins', 'Faasos', 'Faasos', 'Faasos',
#        'Chocolate Heaven', 'Stoner', 'Udupi Park', 'Flavours Of India',
# ...

# %%
wc1=str(wc)
wc1
# Out:
# "['Faasos' 'Faasos' 'Eat Fit' 'Eat Fit' 'Friends Own' 'A2B' 'Bowl Company'\n 'Chai Resto' 'Rice Bowl' 'Grow Fit' 'Maa Bhook Lagi' 'Bowl Company'\n 'Bowl Company' 'A2B' 'Bowl Company' 'A2B' 'A2B' 'Fresh Menu' 'Homely'\n 'Homely' 'Faasos' 'Petoo' 'Refresh' 'A2B' 'A2B' 'A2B' 'Bowl Company'\n 'A2B' 'Homely' 'Keventers' 'Eat Fit' 'Pindi Bangalore' 'Box 8'\n 'Fresh Menu' 'Eat Fit' 'Rajdhani' 'Udupi Park' 'Kitchens' 'Ccd'\n 'Yum Yum Dilli' 'Warm Oven' 'Eat Fit' 'Eat Fit' 'Taco Bell'\n 'Cold Stone Creamery' 'Fresh Menu' 'Cold Stone Creamery'\n 'Mad Over Donuts' 'Rajdhani' 'Indulge' 'Ccd' 'Hyd Biriyani House'\n 'Fresh Menu' 'Udupi Park' 'Keventers' 'Nu.Tree' 'Madurai Express '\n 'Chai Resto' 'Udupi Park' 'Chandrika Tiffins' 'Faasos' 'Faasos' 'Faasos'\n 'Chocolate Heaven' 'Stoner' 'Udupi Park' 'Flavours Of India' 'Wow Momo'\n 'Fresh Menu' 'Ccd' 'Imperio' 'Chai Point' 'Rajdhani' 'Delhi Kitchen'\n 'Dominos' 'Wow Momo' 'Beyond Elements' 'Rajdhani' 'Rajdhani']"

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud(
    width = 2000,
    height = 1000,repeat=False,
    background_color = 'black')

# %%
word_to_frequency=None

# %%
wordcloud.generate_from_frequencies(dic)

# %%
fig = plt.figure(
    figsize = (10, 5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
